# %%
import pandas as pd 
df = pd.read_csv('../../../data/wine-ratings.csv',index_col=0)
df.head(10)
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
# 5    1000 Stories Bourbon Barrel Aged Zinfandel 2016    NaN
# 6    1000 Stories Bourbon Barrel Aged Zinfandel 2017    NaN
# 7                            12 Linajes Crianza 2014    NaN
# 8                            12 Linajes Reserva 2012    NaN
# 9                   14 Hands Cabernet Sauvignon 2010    NaN
#
#                         region   variety  rating  \
# 0        Mendocino, California  Red Wine    91.0
# 1                   California  Red Wine    89.0
# 2                   California  Red Wine    90.0
# 3      North Coast, California  Red Wine    91.0
# 4                   California  Red Wine    90.0
# 5                   California  Red Wine    91.0
# 6                   California  Red Wine    92.0
# 7      Ribera del Duero, Spain  Red Wine    92.0
# 8      Ribera del Duero, Spain  Red Wine    94.0
# 9  Columbia Valley, Washington  Red Wine    87.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...
# 5  1,000 Stories Bourbon barrel-aged Zinfandel is...
# 6  Batch 55 embodies an opulent vintage, which sa...
# 7  Red with violet hues. The aromas are very inte...
# 8  On the nose, a complex predominance of mineral...
# 9  Concentrated aromas of dark stone fruits and t...

# %%
df.drop(columns="grape", axis=1,inplace=True)

# %%
df.dropna()
# Out:
#                                                     name  \
# 0      1000 Stories Bourbon Barrel Aged Batch Blue Ca...
# 1      1000 Stories Bourbon Barrel Aged Gold Rush Red...
# 2      1000 Stories Bourbon Barrel Aged Gold Rush Red...
# 3        1000 Stories Bourbon Barrel Aged Zinfandel 2013
# 4        1000 Stories Bourbon Barrel Aged Zinfandel 2014
# ...                                                  ...
# 32775             Lewis Cellars Syrah Ethan's Blend 2005
# 32776             Lewis Cellars Syrah Ethan's Blend 2014
# 32777             Lewis Cellars Syrah Ethan's Blend 2009
# 32778                            Lexington Apex Red 2011
# 32779       Lexington Gist Ranch Cabernet Sauvignon 2011
#
#                                  region   variety  rating  \
# 0                 Mendocino, California  Red Wine    91.0
# 1                            California  Red Wine    89.0
# 2                            California  Red Wine    90.0
# 3               North Coast, California  Red Wine    91.0
# 4                            California  Red Wine    90.0
# ...                                 ...       ...     ...
# 32775                        California  Red Wine    92.0
# 32776                        California  Red Wine    93.0
# 32777                        California  Red Wine    94.0
# 32778  Santa Cruz Mountains, California  Red Wine    91.0
# 32779  Santa Cruz Mountains, California  Red Wine    91.0
#
#                                                    notes
# 0      This is a very special, limited release of 100...
# 1      The California Gold Rush was a period of coura...
# 2      The California Gold Rush was a period of coura...
# 3      The wine has a deep, rich purple color. An int...
# 4      Batch #004 is the first release of the 2014 vi...
# ...                                                  ...
# 32775  Now 7 years old, Alec's younger brother Ethan ...
# 32776  Born in 2000, everything about Ethan and his n...
# 32777  Positioned between brothers, Alec and Mason, E...
# 32778          Blend: 99% Cabernet Sauvignon, 1% Merlot
# 32779          Blend: 80% Cabernet Sauvignon, 20% Merlot
#
# [32421 rows x 5 columns]

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: typing-extensions in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib) (4.5.0)
# Requirement already satisfied: six>=1.5 in /home/sepideh/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.rating.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x= "rating",y= "variety",alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_29765/297867249.py in <module>
# ----> 1 df.plot.scatter(x= "rating",y= "variety",alpha=0.5)
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwargs)
#    1634             ...                       colormap='viridis')
#    1635         """
# -> 1636         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1637
#    1638     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1075             cmap=cmap,
#    1076             norm=norm,
# -> 1077             **self.kwds,
#    1078         )
#    1079         if cb:
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4360         """
#    4361         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4362         x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4363         # np.ma.ravel yields an ndarray, not a masked array,
#    4364         # unless its argument is a masked array.
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/axes/_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2524             # Update from data if axis is already set but no unit is set yet.
#    2525             if axis is not None and data is not None and not axis.have_units():
# -> 2526                 axis.update_units(data)
#    2527         for axis_name, axis in axis_map.items():
#    2528             # Return if no axis is set.
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/axis.py in update_units(self, data)
#    1447         neednew = self.converter != converter
#    1448         self.converter = converter
# -> 1449         default = self.converter.default_units(data, self)
#    1450         if default is not None and self.units is None:
#    1451             self.set_units(default)
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/category.py in default_units(data, axis)
#     114         # the conversion call stack is default_units -> axis_info -> convert
#     115         if axis.units is None:
# --> 116             axis.set_units(UnitData(data))
#     117         else:
#     118             axis.units.update(data)
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/category.py in __init__(self, data)
#     190         self._counter = itertools.count()
#     191         if data is not None:
# --> 192             self.update(data)
#     193
#     194     @staticmethod
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/category.py in update(self, data)
#     225         for val in OrderedDict.fromkeys(data):
#     226             # OrderedDict just iterates over unique values in data.
# --> 227             _api.check_isinstance((str, bytes), value=val)
#     228             if convertible:
#     229                 # this will only be called so long as convertible is True.
#
# ~/Documents/Source/Repos/Python-Essentials-for-MLOps/venv/lib/python3.7/site-packages/matplotlib/_api/__init__.py in check_isinstance(_types, **kwargs)
#      96                     ", ".join(names[:-1]) + " or " + names[-1]
#      97                     if len(names) > 1 else names[0],
# ---> 98                     type_name(type(v))))
#      99
#     100
#
# TypeError: 'value' must be an instance of str or bytes, not a float
