# %%
import pandas as pd

# %%
df = pd.read_csv('../../../data/wine-ratings.csv',index_col=0)
df.head()
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
#
#                     region   variety  rating  \
# 0    Mendocino, California  Red Wine    91.0
# 1               California  Red Wine    89.0
# 2               California  Red Wine    90.0
# 3  North Coast, California  Red Wine    91.0
# 4               California  Red Wine    90.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...

# %%
df.notes.head()
# Out:
# 0    This is a very special, limited release of 100...
# 1    The California Gold Rush was a period of coura...
# 2    The California Gold Rush was a period of coura...
# 3    The wine has a deep, rich purple color. An int...
# 4    Batch #004 is the first release of the 2014 vi...
# Name: notes, dtype: object

# %%
name_rating=df[["name","rating"]]
name_rating.head()
# Out:
#                                                 name  rating
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    91.0
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    89.0
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    90.0
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    91.0
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    90.0

# %%
top_name_rating= name_rating[df["rating"]>60]
top_name_rating.sort_values(by= df.rating.name ,ascending=True).head()
# Out:
#                                                     name  rating
# 5508               Bodegas Montecillo Crianza Tinto 1998    85.0
# 23298  Forest Glen Barrel Select Merlot (half-bottle)...    85.0
# 21337                         Eola Hills Pinot Noir 1997    85.0
# 6926                  Bridgeview Reserve Pinot Noir 1998    85.0
# 30052  Kenwood Jack London Vineyard Cabernet Sauvigno...    85.0

# %%
df.query("rating >96").head()
# Out:
#                                                  name  grape  \
# 218                     Abreu Vineyards Cappella 2010    NaN
# 220              Abreu Vineyards Howell Mountain 2009    NaN
# 221  Abreu Vineyards Las Posadas Howell Mountain 2012    NaN
# 223                Abreu Vineyards Madrona Ranch 1996    NaN
# 227                Abreu Vineyards Madrona Ranch 2005    NaN
#
#                                        region   variety  rating  \
# 218                   Napa Valley, California  Red Wine    98.0
# 220  Howell Mountain, Napa Valley, California  Red Wine    98.0
# 221  Howell Mountain, Napa Valley, California  Red Wine    99.0
# 223                   Napa Valley, California  Red Wine    98.0
# 227                   Napa Valley, California  Red Wine    98.0
#
#                                                  notes
# 218  Cappella is one of the oldest vineyard sites i...
# 220  As a set of wines, it is hard to surpass the f...
# ...

# %%
df.query("rating >96 & region=='Napa Valley, California'").head()
# Out:
#                                    name  grape                   region  \
# 218       Abreu Vineyards Cappella 2010    NaN  Napa Valley, California
# 223  Abreu Vineyards Madrona Ranch 1996    NaN  Napa Valley, California
# 227  Abreu Vineyards Madrona Ranch 2005    NaN  Napa Valley, California
# 229     Abreu Vineyards Thorevilos 2009    NaN  Napa Valley, California
# 230     Abreu Vineyards Thorevilos 2012    NaN  Napa Valley, California
#
#       variety  rating                                              notes
# 218  Red Wine    98.0  Cappella is one of the oldest vineyard sites i...
# 223  Red Wine    98.0  Abreu Madrona Ranch is a blend of Cabernet Sau...
# 227  Red Wine    98.0  Abreu Madrona Ranch is a blend of Cabernet Sau...
# 229  Red Wine    98.0  The blend for this cuvee is generally an intri...
# 230  Red Wine    99.0  Sitting 800 feet above the valley floor, wedge...

# %%
df.query("rating >96 & region.str.contains('Napa Valley',na=False)").head()
# Out:
#                                                  name  grape  \
# 218                     Abreu Vineyards Cappella 2010    NaN
# 220              Abreu Vineyards Howell Mountain 2009    NaN
# 221  Abreu Vineyards Las Posadas Howell Mountain 2012    NaN
# 223                Abreu Vineyards Madrona Ranch 1996    NaN
# 227                Abreu Vineyards Madrona Ranch 2005    NaN
#
#                                        region   variety  rating  \
# 218                   Napa Valley, California  Red Wine    98.0
# 220  Howell Mountain, Napa Valley, California  Red Wine    98.0
# 221  Howell Mountain, Napa Valley, California  Red Wine    99.0
# 223                   Napa Valley, California  Red Wine    98.0
# 227                   Napa Valley, California  Red Wine    98.0
#
#                                                  notes
# 218  Cappella is one of the oldest vineyard sites i...
# 220  As a set of wines, it is hard to surpass the f...
# ...

# %%
df.query("rating >96 & name.str.contains('Abreu Vineyards',na=False)").head(10)
# Out:
#                                                  name  grape  \
# 218                     Abreu Vineyards Cappella 2010    NaN
# 220              Abreu Vineyards Howell Mountain 2009    NaN
# 221  Abreu Vineyards Las Posadas Howell Mountain 2012    NaN
# 223                Abreu Vineyards Madrona Ranch 1996    NaN
# 227                Abreu Vineyards Madrona Ranch 2005    NaN
# 229                   Abreu Vineyards Thorevilos 2009    NaN
# 230                   Abreu Vineyards Thorevilos 2012    NaN
# 231                   Abreu Vineyards Thorevilos 2014    NaN
# 233                   Abreu Vineyards Thorevilos 2015    NaN
#
#                                        region   variety  rating  \
# 218                   Napa Valley, California  Red Wine    98.0
# 220  Howell Mountain, Napa Valley, California  Red Wine    98.0
# 221  Howell Mountain, Napa Valley, California  Red Wine    99.0
# 223                   Napa Valley, California  Red Wine    98.0
# ...
